# %%
import pandas as pd
import numpy as np

import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from opencage.geocoder import OpenCageGeocode

# %%
df=pd.read_csv('/Users/rahul/Documents/NCI/data/london_economy.csv',encoding='utf-8')
df.head()
# Out:
#         Code                  city working_person total_working  percent  \
# 0  E09000002  Barking and Dagenham         33,600       105,600     31.8
# 1  E09000003                Barnet         51,800       209,800     24.7
# 2  E09000004                Bexley         29,300       139,200     21.0
# 3  E09000005                 Brent         54,600       181,100     30.1
# 4  E09000006               Bromley         36,400       187,700     19.4
#
#    confidence
# 0         3.9
# 1         3.6
# 2         3.6
# 3         3.6
# 4         3.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Code            32 non-null     object
#  1   city            32 non-null     object
#  2   working_person  32 non-null     object
#  3   total_working   32 non-null     object
#  4   percent         32 non-null     float64
#  5   confidence      32 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 1.6+ KB

# %%
locator = Nominatim(user_agent="myGeocoder")
location = locator.geocode("Barking and Dagenham")

# %%
df.shape[0]
# Out:
# 32

# %%
def get_lat_long(city):
    locator=Nominatim(user_agent="myGeocoder")
    location=locator.geocode(city)
    return location.latitude,location.longitude

# %%
for i in range(df.shape[0]):
    latitude,longitude=get_lat_long(df['city'][i])
    df['latitude']=latitude
    df['longitude']=longitude

# %%
df.head()
# Out:
#         Code                  city working_person total_working  percent  \
# 0  E09000002  Barking and Dagenham         33,600       105,600     31.8
# 1  E09000003                Barnet         51,800       209,800     24.7
# 2  E09000004                Bexley         29,300       139,200     21.0
# 3  E09000005                 Brent         54,600       181,100     30.1
# 4  E09000006               Bromley         36,400       187,700     19.4
#
#    confidence   latitude  longitude
# 0         3.9  51.500444   -0.12654
# 1         3.6  51.500444   -0.12654
# 2         3.6  51.500444   -0.12654
# 3         3.6  51.500444   -0.12654
# 4         3.2  51.500444   -0.12654

# %%
print("Latitude = {}, Longitude = {}".format(location.latitude, location.longitude))
# Out:
# Latitude = 51.5541171, Longitude = 0.15050434261994267

# %%
df_k=pd.read_csv('/Users/rahul/Documents/NCI/data/Kaagle_Upload.csv',encoding='utf-8')
df_k.head()
# Out:
# /Users/rahul/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (0,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   accident_index  vehicle_reference  vehicle_type  towing_and_articulation  \
# 0  201506E098757                  2             9                        0
# 1  201506E098766                  1             9                        0
# 2  201506E098766                  2             9                        0
# 3  201506E098777                  1            20                        0
# 4  201506E098780                  1             9                        0
#
#    vehicle_manoeuvre  vehicle_location-restricted_lane  junction_location  \
# 0                 18                                 0                  8
# 1                  9                                 0                  8
# ...

# %%
df_k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285331 entries, 0 to 285330
# Data columns (total 70 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   accident_index                                    285331 non-null  object
#  1   vehicle_reference                                 285331 non-null  int64
#  2   vehicle_type                                      285331 non-null  int64
#  3   towing_and_articulation                           285331 non-null  int64
#  4   vehicle_manoeuvre                                 285331 non-null  int64
#  5   vehicle_location-restricted_lane                  285331 non-null  int64
#  6   junction_location                                 285331 non-null  int64
#  7   skidding_and_overturning                          285331 non-null  int64
#  8   hit_object_in_carriageway                         285331 non-null  int64
# ...

# %%
df_k[['latitude','longitude']].head()
# Out:
#     latitude  longitude
# 0  53.450014  -2.227629
# 1  53.446296  -2.244322
# 2  53.446296  -2.244322
# 3  53.457881  -2.201617
# 4  53.453319  -2.238188

# %%
## Fetch only london near by rows

# %%
df_lat_london=df_k[(df_k['latitude']> 50.5074) &  (df_k['latitude'] <52.5074)
                           &  (df_k['longitude'] >0.1178) & (df_k['longitude']<0.1378)]

# %%
df_lat_london[['latitude','longitude']].head()
# Out:
#        latitude  longitude
# 16859  51.58216   0.118793
# 16860  51.58216   0.118793
# 16861  51.58216   0.118793
# 16862  51.58216   0.118793
# 16939  51.56309   0.119060

# %%
df_lat_london.head()
# Out:
#       accident_index  vehicle_reference  vehicle_type  \
# 16859  201501JI40037                  1             9
# 16860  201501JI40037                  1             9
# 16861  201501JI40037                  1             9
# 16862  201501JI40037                  2            19
# 16939  201501JI40086                  1             1
#
#        towing_and_articulation  vehicle_manoeuvre  \
# 16859                        0                  3
# 16860                        0                  3
# 16861                        0                  3
# 16862                        0                 18
# 16939                        0                 18
#
#        vehicle_location-restricted_lane  junction_location  \
# 16859                                 0                  0
# 16860                                 0                  0
# 16861                                 0                  0
# 16862                                 0                  0
# ...

# %%
df_lat_london.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1109 entries, 16859 to 234696
# Data columns (total 70 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   accident_index                                    1109 non-null   object
#  1   vehicle_reference                                 1109 non-null   int64
#  2   vehicle_type                                      1109 non-null   int64
#  3   towing_and_articulation                           1109 non-null   int64
#  4   vehicle_manoeuvre                                 1109 non-null   int64
#  5   vehicle_location-restricted_lane                  1109 non-null   int64
#  6   junction_location                                 1109 non-null   int64
#  7   skidding_and_overturning                          1109 non-null   int64
#  8   hit_object_in_carriageway                         1109 non-null   int64
# ...

# %%
df_lat_long=df_k[['latitude','longitude']]

# %%
df_lat_long.head()
# Out:
#     latitude  longitude
# 0  53.450014  -2.227629
# 1  53.446296  -2.244322
# 2  53.446296  -2.244322
# 3  53.457881  -2.201617
# 4  53.453319  -2.238188

# %%
df_lat_long.describe()
# Out:
#             latitude      longitude
# count  285270.000000  285270.000000
# mean       52.497308      -1.336064
# std         1.401328       1.384093
# min        49.915618      -7.422915
# 25%        51.478216      -2.216374
# 50%        52.092339      -1.260807
# 75%        53.416855      -0.182354
# max        60.661117       1.758443

# %%
def fun_isLondon(latitude,longitude):
    if latitude> 50.5074 and  latitude <52.5074 and  longitude >0.1178 and longitude<0.1378:
        return True
    else:
        return False

# %%
df_lat_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285331 entries, 0 to 285330
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   latitude   285270 non-null  float64
#  1   longitude  285270 non-null  float64
# dtypes: float64(2)
# memory usage: 4.4 MB

# %%
df_lat_london=df_lat_long[(df_lat_long['latitude']> 50.5074) &  (df_lat_long['latitude'] <52.5074)
                           &  (df_lat_long['longitude'] >0.1178) & (df_lat_long['longitude']<0.1378)]

# %%
df_lat_london
# Out:
#          latitude  longitude
# 16859   51.582160   0.118793
# 16860   51.582160   0.118793
# 16861   51.582160   0.118793
# 16862   51.582160   0.118793
# 16939   51.563090   0.119060
# ...           ...        ...
# 234188  50.989683   0.132664
# 234189  50.989683   0.132664
# 234337  50.931742   0.132389
# 234695  51.101021   0.133213
# 234696  51.101021   0.133213
#
# [1109 rows x 2 columns]

# %%
locator=Nominatim(user_agent="myGeocoder")
coordinates="51.5074,0.1278"
location=locator.reverse(coordinates)
location.raw
# Out:
# {'place_id': 80604443,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 5181183,
#  'lat': '51.5075415',
#  'lon': '0.1280774',
#  'display_name': 'Fleming Way, London Borough of Bexley, London, Greater London, England, SE28 8NS, United Kingdom',
#  'address': {'road': 'Fleming Way',
#   'city_district': 'London Borough of Bexley',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'postcode': 'SE28 8NS',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  'boundingbox': ['51.5071355', '51.5079528', '0.1280173', '0.1292619']}

# %%
#end

# %% [markdown]
# ## Google map API

# %%
df_2015 = pd.read_csv('/Users/rahul/Documents/NCI/data/2015.csv',encoding='utf-8')

# %%
df_2015.head()
# Out:
#         Code                  Area Economically Inactive; Jan 2015-Dec 2015  \
# 0  E09000001        City of London                                    2,000
# 1  E09000002  Barking and Dagenham                                   33,400
# 2  E09000003                Barnet                                   60,300
# 3  E09000004                Bexley                                   28,500
# 4  E09000005                 Brent                                   54,600
#
#   Working age; Jan 2015-Dec 2015  percent; Jan 2015-Dec 2015  \
# 0                           5600                          36
# 1                       1,28,300                          26
# 2                       2,44,000                          25
# 3                       1,52,400                          19
# 4                       2,19,400                          25
#
#   confidence; Jan 2015-Dec 2015
# 0                             *
# 1                           3.7
# 2                           3.7
# ...

# %%
# !pip install google-api-python-client
# Out:
# ...
#      |████████████████████████████████| 61 kB 2.3 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 95 kB 2.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 114 kB 8.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 91 kB 8.4 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 100 kB 9.4 MB/s eta 0:00:01
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.11.3
#     Uninstalling google-auth-1.11.3:
#       Successfully uninstalled google-auth-1.11.3
# ...

# %%
from apiclient.discovery import build

# %%
from googlemaps import Client as GoogleMaps
import pandas as pd 
import json

# %%
gmaps = GoogleMaps("AIzaSyDLPFRVev0uQ5-IfpmNf-Ek3c9H6ZBS5sA")

# %%
df_2015_london= pd.read_csv('/Users/rahul/Documents/NCI/data/2015.csv',encoding='utf-8')
df_2015_london.head()
# Out:
#         Code                  Area Economically Inactive; Jan 2015-Dec 2015  \
# 0  E09000001        City of London                                    2,000
# 1  E09000002  Barking and Dagenham                                   33,400
# 2  E09000003                Barnet                                   60,300
# 3  E09000004                Bexley                                   28,500
# 4  E09000005                 Brent                                   54,600
#
#   Working age; Jan 2015-Dec 2015  percent; Jan 2015-Dec 2015  \
# 0                           5600                          36
# 1                       1,28,300                          26
# 2                       2,44,000                          25
# 3                       1,52,400                          19
# 4                       2,19,400                          25
#
#   confidence; Jan 2015-Dec 2015
# 0                             *
# 1                           3.7
# 2                           3.7
# ...

# %%
df_2015_london["latitude"]= ""
df_2015_london["longitude"]= ""

# %%
for x in range(len(df_2015_london)):
    try:        
        geocode_result = gmaps.geocode(df_2015_london['Area'][x])
      # df_2015_london["latitude"][x] = geocode_result[0]["latitude"]
       #df_2015_london["longitude"][x] = geocode_result[0]["longitude"]
        #print(geocode_result["address_components"]["geometery"]["bounds"]["southwest"])
        data = json.dumps(geocode_result)
        data = json.loads(data)
        for value in data :
            bound=value['geometry']['bounds']
            df_2015_london["latitude"][x]=bound['southwest']['lat']
            df_2015_london["longitude"][x]=bound['southwest']['lng']
    except IndexError:
        print("Area was wrong...")
    except Exception as e:
        print("Unexpected error occurred.", e )
df_2015_london.head()
# Out:
# <ipython-input-31-935e86d5ce98>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2015_london["latitude"][x]=bound['southwest']['lat']
# <ipython-input-31-935e86d5ce98>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2015_london["longitude"][x]=bound['southwest']['lng']
# Unexpected error occurred. 'bounds'
# Unexpected error occurred. 'bounds'
# Unexpected error occurred. 'bounds'
# Unexpected error occurred. 'bounds'
# Unexpected error occurred. 'bounds'
# Unexpected error occurred. 'bounds'
# Unexpected error occurred. 'bounds'
# Unexpected error occurred. 'bounds'
# ...

# %%
df_2015_london.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Code                                      51 non-null     object
#  1   Area                                      51 non-null     object
#  2   Economically Inactive; Jan 2015-Dec 2015  51 non-null     object
#  3   Working age; Jan 2015-Dec 2015            51 non-null     object
#  4   percent; Jan 2015-Dec 2015                51 non-null     int64
#  5   confidence; Jan 2015-Dec 2015             51 non-null     object
#  6   latitude                                  51 non-null     object
#  7   longitude                                 51 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 3.3+ KB

# %%
df_2015_london['latitude']
# Out:
# 0     51.5068
# 1     51.5088
# 2     51.6357
# 3     39.9474
# 4     35.3231
# 5
# 6     39.8987
# 7     51.3298
# 8     51.4905
# 9     41.9343
# 10    40.9509
# 11    51.5198
# 12    51.4639
# 13    51.5646
# 14    51.5531
# 15    51.4841
# 16    51.4533
# 17    51.4207
# 18    51.5185
# 19    51.4772
# 20    51.3977
# 21     51.411
# 22    51.4136
# 23
# 24     51.496
# 25
# 26    51.3914
# 27
# 28    42.0817
# 29    51.4845
# 30    51.5499
# 31    51.4178
# 32    39.5464
# 33     51.411
# 34
# 35
# 36
# 37    53.3015
# 38
# 39    52.3477
# 40
# 41    51.3849
# 42
# 43
# 44     51.375
# 45    54.6332
# 46    54.0226
# 47    49.8647
# 48
# 49    34.5614
# 50    34.5614
# Name: latitude, dtype: object

# %%
key_file=''# need to be updated
try:
    file= open(key_file,'r')
    key_dic={}
    for f in file.readlines():
        if f!='\n':
            f=f.replace('\n','')
            key_value=f.split(':')
            key_dic[key_value[0]]=key_value[1]
except IOError as e:
    print('File reading error',e)

# %%
try:
    tweets_data_path = "twitter_data.txt"  
    tweets_file=open(tweets_data_path,'w')
except IOError as e:
    print(e)

# %%
ac_df=pd.read_csv('/Users/rahul/Documents/NCI/data/Kaagle_Upload.csv')
ac_df.head()
# Out:
# /Users/rahul/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   accident_index  vehicle_reference  vehicle_type  towing_and_articulation  \
# 0  201506E098757                  2             9                        0
# 1  201506E098766                  1             9                        0
# 2  201506E098766                  2             9                        0
# 3  201506E098777                  1            20                        0
# 4  201506E098780                  1             9                        0
#
#    vehicle_manoeuvre  vehicle_location-restricted_lane  junction_location  \
# 0                 18                                 0                  8
# 1                  9                                 0                  8
# ...

# %%
ac_df[['longitude','latitude','pedestrian_location']].head()
# Out:
#    longitude   latitude  pedestrian_location
# 0  -2.227629  53.450014                  NaN
# 1  -2.244322  53.446296                  NaN
# 2  -2.244322  53.446296                  0.0
# 3  -2.201617  53.457881                  1.0
# 4  -2.238188  53.453319                  NaN

# %%
ac_df[['longitude','latitude']].describe()
# Out:
#            longitude       latitude
# count  285270.000000  285270.000000
# mean       -1.336064      52.497308
# std         1.384093       1.401328
# min        -7.422915      49.915618
# 25%        -2.216374      51.478216
# 50%        -1.260807      52.092339
# 75%        -0.182354      53.416855
# max         1.758443      60.661117

# %%
min_longitude=ac_df['longitude'].min()
max_longitude=ac_df['longitude'].max()
min_latitude=ac_df['latitude'].min()
max_latitude=ac_df['latitude'].max()

# %%
ac_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285331 entries, 0 to 285330
# Data columns (total 70 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   accident_index                                    285331 non-null  object
#  1   vehicle_reference                                 285331 non-null  int64
#  2   vehicle_type                                      285331 non-null  int64
#  3   towing_and_articulation                           285331 non-null  int64
#  4   vehicle_manoeuvre                                 285331 non-null  int64
#  5   vehicle_location-restricted_lane                  285331 non-null  int64
#  6   junction_location                                 285331 non-null  int64
#  7   skidding_and_overturning                          285331 non-null  int64
#  8   hit_object_in_carriageway                         285331 non-null  int64
# ...

# %%
#Import the necessary methods from tweepy library
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import re

# Enter Twitter API Keys
access_token = key_dic['Access_token']
access_token_secret = key_dic['Access_token_secret']
consumer_key = key_dic['Api_Key']
consumer_secret = key_dic['Api_secret_key']
#Accident #fatal #prayer #highway #driving #trucker #trucking #wrongway #reckless #carelessdriving #dashcam
#Accident #fatal #prayer #highway #driving #trucker #trucking #wrongway #reckless #carelessdriving #dashcam
#geocode = "%f,%f,%dkm" % (latitude, longitude, max_range)
# Create tracklist with the words that will be searched for
#tracklist = ['#covid19', '#lockdown', '#socialdistancing']
tracklist = ['#Accident', '#fatal','#wrongdriving','#wrongway','#reckless','#carelessdriving']
# Initialize Global variable
tweet_count = 0
# Input number of tweets to be downloaded
n_tweets = 10



# Create the class that will handle the tweet stream
class StdOutListener(StreamListener):
      
    def on_data(self, data):
        global tweet_count
        global n_tweets
        global stream
        if tweet_count < n_tweets:
            tweets_file.writelines(data)
            tweet_count += 1
            return True
        else:
            stream.disconnect()

    def on_error(self, status):
        print(status)



# Handles Twitter authetification and the connection to Twitter Streaming API
l = StdOutListener()
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
stream = Stream(auth, l)
#stream.filter(track=tracklist,location=[max_latitude,min_latitude,max_longitude,min_longitude])
stream.filter(track=tracklist,geocode="38.909770,-77.045202,0.15mi")

tweets_file.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-bcb323a26e45> in <module>
#      48 stream = Stream(auth, l)
#      49 #stream.filter(track=tracklist,location=[max_latitude,min_latitude,max_longitude,min_longitude])
# ---> 50 stream.filter(track=tracklist,geocode="38.909770,-77.045202,0.15mi")
#      51
#      52 tweets_file.close()
#
# TypeError: filter() got an unexpected keyword argument 'geocode'

# %%
search_words = "#coronavirus OR #covid19 OR #lockdown"
date_since = "2020-03-10"
geocodes = "20.593700, 78.962900, 100km"

# %%
import tweepy as tw

# %%
tweets = tw.Cursor(api.search,
              q=search_words,
              geocode=geocodes,
              lang="en",
              since=date_since).items(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-fcd004e51ec3> in <module>
# ----> 1 tweets = tw.Cursor(api.search,
#       2               q=search_words,
#       3               geocode=geocodes,
#       4               lang="en",
#       5               since=date_since).items(100)
#
# NameError: name 'api' is not defined

# %%
from twitter import *

import sys
import csv

latitude = 51.474144    # geographical centre of search
longitude = -0.035401    # geographical centre of search
max_range = 1             # search range in kilometres
num_results = 50        # minimum results to obtain
outfile = "output.csv"

#-----------------------------------------------------------------------
# load our API credentials
#-----------------------------------------------------------------------
import sys
sys.path.append(".")
import config

#-----------------------------------------------------------------------
# create twitter API object
#-----------------------------------------------------------------------
twitter = Twitter(auth = OAuth(consumer_key,
                  cconsumer_secret,
                  access_token,access_token_secret))

#-----------------------------------------------------------------------
# open a file to write (mode "w"), and create a CSV writer object
#-----------------------------------------------------------------------
csvfile = open(outfile, "w")
csvwriter = csv.writer(csvfile)

#-----------------------------------------------------------------------
# add headings to our CSV file
#-----------------------------------------------------------------------
row = [ "user", "text", "latitude", "longitude" ]
csvwriter.writerow(row)

#-----------------------------------------------------------------------
# the twitter API only allows us to query up to 100 tweets at a time.
# to search for more, we will break our search up into 10 "pages", each
# of which will include 100 matching tweets.
#-----------------------------------------------------------------------
result_count = 0
last_id = None
while result_count <  num_results:
    #-----------------------------------------------------------------------
    # perform a search based on latitude and longitude
    # twitter API docs: https://dev.twitter.com/rest/reference/get/search/tweets
    #-----------------------------------------------------------------------
    query = twitter.search.tweets(q = "", geocode = "%f,%f,%dkm" % (latitude, longitude, max_range), count = 100, max_id = last_id)

    for result in query["statuses"]:
        #-----------------------------------------------------------------------
        # only process a result if it has a geolocation
        #-----------------------------------------------------------------------
        if result["geo"]:
            user = result["user"]["screen_name"]
            text = result["text"]
            text = text.encode('ascii', 'replace')
            latitude = result["geo"]["coordinates"][0]
            longitude = result["geo"]["coordinates"][1]

            #-----------------------------------------------------------------------
            # now write this row to our CSV file
            #-----------------------------------------------------------------------
            row = [ user, text, latitude, longitude ]
            csvwriter.writerow(row)
            result_count += 1
        last_id = result["id"]

    #-----------------------------------------------------------------------
    # let the user know where we're up to
    #-----------------------------------------------------------------------
    print("got %d results" % result_count)

#-----------------------------------------------------------------------
# we're all finished, clean up and go home.
#-----------------------------------------------------------------------
csvfile.close()

print("written to %s" % outfile)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-a49dd5dcfb0a> in <module>
# ----> 1 from twitter import *
#       2
#       3 import sys
#       4 import csv
#       5
#
# ModuleNotFoundError: No module named 'twitter'

# %%
# !pip install twitter
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
# ...
#     100% |████████████████████████████████| 61kB 1.0MB/s ta 0:00:011
# ...
# Could not install packages due to an EnvironmentError: [Errno 13] Permission denied: '/Library/Python/2.7/site-packages/twitter'
# Consider using the `--user` option or check the permissions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import statsmodels.api as sm
# %matplotlib inline
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt   
from sklearn import metrics

# %%
df=pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age  gender   bmi  children  smoker     region     claim
# 0   19  female  27.9         0       1  southwest  16884.92
# 1   18    male  33.8         1       0  southeast   1725.55
# 2   28    male  33.0         3       0  southeast   4449.46
# 3   33    male  22.7         0       0  northwest  21984.47
# 4   32    male  28.9         0       0  northwest   3866.86

# %%
df.describe()
# Out:
#                age          bmi     children       smoker         claim
# count  1338.000000  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918     0.204783  13270.422414
# std      14.049960     6.098382     1.205493     0.403694  12110.011240
# min      18.000000    16.000000     0.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000     0.000000   9382.030000
# 75%      51.000000    34.700000     2.000000     0.000000  16639.915000
# max      64.000000    53.100000     5.000000     1.000000  63770.430000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# gender      1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null int64
# region      1338 non-null object
# claim       1338 non-null float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 73.2+ KB

# %%
df.columns
# Out:
# Index([u'age', u'gender', u'bmi', u'children', u'smoker', u'region', u'claim'], dtype='object')

# %%
X=df.drop(columns={'claim'})

# %%
Y=df['claim']

# %%
plt.hist(Y)
plt.show()

# %%
df.describe(include='object')
# Out:
#        gender     region
# count    1338       1338
# unique      2          4
# top      male  southeast
# freq      676        364

# %%
sns.boxplot(x='smoker',y='claim',data=df)
plt.show()

# %%
sns.heatmap(df.corr(), annot=True)

# %%
df2=df.copy()

# %%
df2=df2.groupby('smoker')

# %%
df2.head()
# Out:
#     age  gender   bmi  children  smoker     region     claim
# 0    19  female  27.9         0       1  southwest  16884.92
# 1    18    male  33.8         1       0  southeast   1725.55
# 2    28    male  33.0         3       0  southeast   4449.46
# 3    33    male  22.7         0       0  northwest  21984.47
# 4    32    male  28.9         0       0  northwest   3866.86
# 5    31  female  25.7         0       0  southeast   3756.62
# 11   62  female  26.3         0       1  southeast  27808.73
# 14   27    male  42.1         0       1  southeast  39611.76
# 19   30    male  35.3         0       1  southwest  36837.47
# 23   34  female  31.9         1       1  northeast  37701.88

# %%
pd.options.display.max_columns=None

# %%
df2.describe()
# Out:
#            age                                                          bmi  \
#          count       mean        std   min    25%   50%   75%   max   count
# smoker
# 0       1064.0  39.385338  14.083410  18.0  26.75  40.0  52.0  64.0  1064.0
# 1        274.0  38.514599  13.923186  18.0  27.00  38.0  49.0  64.0   274.0
#
#                                                            children            \
#              mean       std   min   25%    50%   75%   max    count      mean
# smoker
# 0       30.653195  6.042763  16.0  26.3  30.35  34.4  53.1   1064.0  1.090226
# 1       30.713139  6.320840  17.2  26.1  30.45  35.2  52.6    274.0  1.113139
#
#                                             claim                              \
#              std  min  25%  50%  75%  max   count          mean           std
# smoker
# 0       1.218136  0.0  0.0  1.0  2.0  5.0  1064.0   8434.268449   5993.781756
# 1       1.157066  0.0  0.0  1.0  2.0  5.0   274.0  32050.231971  11541.547338
#
#
# ...

# %%
df3=pd.get_dummies(df,drop_first=True)
df3.head()
# Out:
#    age   bmi  children  smoker     claim  gender_male  region_northwest  \
# 0   19  27.9         0       1  16884.92            0                 0
# 1   18  33.8         1       0   1725.55            1                 0
# 2   28  33.0         3       0   4449.46            1                 0
# 3   33  22.7         0       0  21984.47            1                 1
# 4   32  28.9         0       0   3866.86            1                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
X=df3.drop(columns={'claim'})
Y=df3['claim']

# %%
df.head()
# Out:
#    age  gender   bmi  children  smoker     region     claim
# 0   19  female  27.9         0       1  southwest  16884.92
# 1   18    male  33.8         1       0  southeast   1725.55
# 2   28    male  33.0         3       0  southeast   4449.46
# 3   33    male  22.7         0       0  northwest  21984.47
# 4   32    male  28.9         0       0  northwest   3866.86

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (936, 8)
# (402, 8)
# (936,)
# (402,)

# %%
lin_reg=LinearRegression()
model=lin_reg.fit(X_train,Y_train)
print('R^2 for train:',lin_reg.score(X_train,Y_train))
print('R^2 for test:',lin_reg.score(X_test,Y_test))
# Out:
# ('R^2 for train:', 0.7545770426577549)
# ('R^2 for test:', 0.7406005660648991)

# %%
import warnings
warnings.filterwarnings('ignore')

X_constant=sm.add_constant(X)
lin_reg=sm.OLS(Y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  claim   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     500.9
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):               0.00
# Time:                        16:24:07   Log-Likelihood:                -13548.
# No. Observations:                1338   AIC:                         2.711e+04
# Df Residuals:                    1329   BIC:                         2.716e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.tsa.api as smt
acf=smt.graphics.plot_acf(lin_reg.resid,lags=40,alpha=0.5)
acf.show()

# %% [raw]
# smoker will spend $23850 more then the non smoker
# male will spend less $131 then female

# %%
import seaborn as sns

sns.distplot(lin_reg.resid)

# %%
df4=df3.copy()
df4.head()
# Out:
#    age   bmi  children  smoker     claim  gender_male  region_northwest  \
# 0   19  27.9         0       1  16884.92            0                 0
# 1   18  33.8         1       0   1725.55            1                 0
# 2   28  33.0         3       0   4449.46            1                 0
# 3   33  22.7         0       0  21984.47            1                 1
# 4   32  28.9         0       0   3866.86            1                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
X=df.drop(columns={'claim','gender','region'})
Y=df['claim']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (936, 4)
# (402, 4)
# (936,)
# (402,)

# %%
lin_reg=LinearRegression()
model=lin_reg.fit(X_train,Y_train)
print('R^2 for train:',lin_reg.score(X_train,Y_train))
print('R^2 for test:',lin_reg.score(X_test,Y_test))
# Out:
# ('R^2 for train:', 0.7534877516215435)
# ('R^2 for test:', 0.7391979810361154)

# %% [raw]
# bmi>=30 1 and bmi<30 0

# %%
df3.head()
# Out:
#    age   bmi  children  smoker     claim  gender_male  region_northwest  \
# 0   19  27.9         0       1  16884.92            0                 0
# 1   18  33.8         1       0   1725.55            1                 0
# 2   28  33.0         3       0   4449.46            1                 0
# 3   33  22.7         0       0  21984.47            1                 1
# 4   32  28.9         0       0   3866.86            1                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
df2=df.copy()
df2.head()
# Out:
#    age  gender   bmi  children  smoker     region     claim
# 0   19  female  27.9         0       1  southwest  16884.92
# 1   18    male  33.8         1       0  southeast   1725.55
# 2   28    male  33.0         3       0  southeast   4449.46
# 3   33    male  22.7         0       0  northwest  21984.47
# 4   32    male  28.9         0       0  northwest   3866.86

# %%
df2['bin_bmi']=df2['bmi'].apply(lambda x:1 if x>=30 else 0)

# %%
df2.head()
# Out:
#    age  gender   bmi  children  smoker     region     claim  bin_bmi
# 0   19  female  27.9         0       1  southwest  16884.92        0
# 1   18    male  33.8         1       0  southeast   1725.55        1
# 2   28    male  33.0         3       0  southeast   4449.46        1
# 3   33    male  22.7         0       0  northwest  21984.47        0
# 4   32    male  28.9         0       0  northwest   3866.86        0

# %%
df2.drop(columns={'bmi','gender','region'},inplace=True)

# %%
df2.head()
# Out:
#    age  children  smoker     claim  bin_bmi
# 0   19         0       1  16884.92        0
# 1   18         1       0   1725.55        1
# 2   28         3       0   4449.46        1
# 3   33         0       0  21984.47        0
# 4   32         0       0   3866.86        0

# %%
X=df2.drop(columns={'claim'})
Y=df2['claim']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (936, 4)
# (402, 4)
# (936,)
# (402,)

# %%
lin_reg=LinearRegression()
model=lin_reg.fit(X_train,Y_train)
print('R^2 for train:',lin_reg.score(X_train,Y_train))
print('R^2 for test:',lin_reg.score(X_test,Y_test))
# Out:
# ('R^2 for train:', 0.7586859974550313)
# ('R^2 for test:', 0.739185858528652)

# %% [raw]
# after applying bining train data R^2 square value increase not increses very significantly
# R

# %%
df4=df.copy()
df4.head()
# Out:
#    age  gender   bmi  children  smoker     region     claim
# 0   19  female  27.9         0       1  southwest  16884.92
# 1   18    male  33.8         1       0  southeast   1725.55
# 2   28    male  33.0         3       0  southeast   4449.46
# 3   33    male  22.7         0       0  northwest  21984.47
# 4   32    male  28.9         0       0  northwest   3866.86

# %%
df4['bmi_smoker']=df4['bmi']*df4['smoker']

# %%
df4.head()
# Out:
#    age  gender   bmi  children  smoker     region     claim  bmi_smoker
# 0   19  female  27.9         0       1  southwest  16884.92        27.9
# 1   18    male  33.8         1       0  southeast   1725.55         0.0
# 2   28    male  33.0         3       0  southeast   4449.46         0.0
# 3   33    male  22.7         0       0  northwest  21984.47         0.0
# 4   32    male  28.9         0       0  northwest   3866.86         0.0

# %%
X=df4.drop(columns={'gender','region','claim'})

# %%
df4.head()
# Out:
#    age  gender   bmi  children  smoker     region     claim  bmi_smoker
# 0   19  female  27.9         0       1  southwest  16884.92        27.9
# 1   18    male  33.8         1       0  southeast   1725.55         0.0
# 2   28    male  33.0         3       0  southeast   4449.46         0.0
# 3   33    male  22.7         0       0  northwest  21984.47         0.0
# 4   32    male  28.9         0       0  northwest   3866.86         0.0

# %%
Y=df4['claim']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
lin_reg=LinearRegression()
model=lin_reg.fit(X_train,Y_train)
print('R^2 for train:',lin_reg.score(X_train,Y_train))
print('R^2 for test:',lin_reg.score(X_test,Y_test))
# Out:
# ('R^2 for train:', 0.8366713976492387)
# ('R^2 for test:', 0.8433016873043822)

# %%
import warnings
warnings.filterwarnings('ignore')

X_constant=sm.add_constant(X)
lin_reg=sm.OLS(Y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  claim   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     1387.
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):               0.00
# Time:                        16:24:44   Log-Likelihood:                -13256.
# No. Observations:                1338   AIC:                         2.652e+04
# Df Residuals:                    1332   BIC:                         2.656e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2724.5489    831.162     -3.278      0.001   -4355.079   -1094.019
# ...

# %%
import statsmodels.tsa.api as smt

acf = smt.graphics.plot_acf(lin_reg.resid, lags=40 , alpha=0.05)
acf.show()

# %%
import seaborn as sns

sns.distplot(lin_reg.resid)

# %%
#Log transform

# %%
df5=df4.copy()
df5.head()
# Out:
#    age  gender   bmi  children  smoker     region     claim  bmi_smoker
# 0   19  female  27.9         0       1  southwest  16884.92        27.9
# 1   18    male  33.8         1       0  southeast   1725.55         0.0
# 2   28    male  33.0         3       0  southeast   4449.46         0.0
# 3   33    male  22.7         0       0  northwest  21984.47         0.0
# 4   32    male  28.9         0       0  northwest   3866.86         0.0

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
# age           1338 non-null int64
# gender        1338 non-null object
# bmi           1338 non-null float64
# children      1338 non-null int64
# smoker        1338 non-null int64
# region        1338 non-null object
# claim         1338 non-null float64
# bmi_smoker    1338 non-null float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 83.7+ KB

# %%
X=df5.drop(columns={'gender','region','claim'})

# %%
Y=df['claim']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 5 columns):
# age           1338 non-null float64
# bmi           1338 non-null float64
# children      1338 non-null float64
# smoker        1338 non-null float64
# bmi_smoker    1338 non-null float64
# dtypes: float64(5)
# memory usage: 52.3 KB

# %%
X=X.transform(lambda X:np.exp(X))

# %%
Y=Y.transform(lambda Y:np.exp(Y))

# %%
X_constant=sm.add_constant(X)
lin_reg=sm.OLS(Y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  claim   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     1387.
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):               0.00
# Time:                        16:31:55   Log-Likelihood:                -13256.
# No. Observations:                1338   AIC:                         2.652e+04
# Df Residuals:                    1332   BIC:                         2.656e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2724.5489    831.162     -3.278      0.001   -4355.079   -1094.019
# ...

# %%
X=df5.drop(columns={'gender','region','claim'})

# %%
Y=df['claim']

# %%
Y=Y.transform(lambda Y:np.log(Y))

# %%
X_constant=sm.add_constant(X)
lin_reg=sm.OLS(Y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  claim   R-squared:                       0.777
# Model:                            OLS   Adj. R-squared:                  0.776
# Method:                 Least Squares   F-statistic:                     927.5
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):               0.00
# Time:                        16:33:52   Log-Likelihood:                -782.32
# No. Observations:                1338   AIC:                             1577.
# Df Residuals:                    1332   BIC:                             1608.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.2723      0.074     97.907      0.000       7.127       7.418
# ...

# %%
#Linearity of residuals

# %%
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'
import seaborn as sns 
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
sns.set_style('darkgrid')
sns.mpl.rcParams['figure.figsize'] = (15.0, 9.0)

def linearity_test(model, y):
    '''
    Function for visually inspecting the assumption of linearity in a linear regression model.
    It plots observed vs. predicted values and residuals vs. predicted values.
    
    Args:
    * model - fitted OLS model from statsmodels
    * y - observed values
    '''
    fitted_vals = model.predict()
    resids = model.resid

    fig, ax = plt.subplots(1,2)
    
    sns.regplot(x=fitted_vals, y=y, lowess=True, ax=ax[0], line_kws={'color': 'red'})
    ax[0].set_title('Observed vs. Predicted Values', fontsize=16)
    ax[0].set(xlabel='Predicted', ylabel='Observed')

    sns.regplot(x=fitted_vals, y=resids, lowess=True, ax=ax[1], line_kws={'color': 'red'})
    ax[1].set_title('Residuals vs. Predicted Values', fontsize=16)
    ax[1].set(xlabel='Predicted', ylabel='Residuals')
    
linearity_test(lin_reg, Y)

# %%
import statsmodels.api as sm
sm.stats.diagnostic.linear_rainbow(res=lin_reg, frac=0.5)
# Out:
# (1.1101193619782477, 0.08899847826965619)

# %%
import scipy.stats as stats
import pylab
from statsmodels.graphics.gofplots import ProbPlot
st_residual = lin_reg.get_influence().resid_studentized_internal
stats.probplot(st_residual, dist="norm", plot = pylab)
plt.show()

# %%
lin_reg.resid.mean()
# Out:
# -1.6456552115039307e-12

# %%
#Goldfeld Test

# %%
from statsmodels.compat import lzip
import numpy as np
from statsmodels.compat import lzip
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'
import seaborn as sns 
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
sns.set_style('darkgrid')
sns.mpl.rcParams['figure.figsize'] = (15.0, 9.0)

model = lin_reg
fitted_vals = model.predict()
resids = model.resid
resids_standardized = model.get_influence().resid_studentized_internal
fig, ax = plt.subplots(1,2)

sns.regplot(x=fitted_vals, y=resids, lowess=True, ax=ax[0], line_kws={'color': 'red'})
ax[0].set_title('Residuals vs Fitted', fontsize=16)
ax[0].set(xlabel='Fitted Values', ylabel='Residuals')
sns.regplot(x=fitted_vals, y=np.sqrt(np.abs(resids_standardized)), lowess=True, ax=ax[1], line_kws={'color': 'red'})
ax[1].set_title('Scale-Location', fontsize=16)
ax[1].set(xlabel='Fitted Values', ylabel='sqrt(abs(Residuals))')

name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(model.resid, model.model.exog)
lzip(name, test)
# Out:
# [('F statistic', 0.9834031776076885), ('p-value', 0.5852662429372382)]

# %% [raw]
# p-value>alpha so null hyphothesis is accepted.(there is constant variance)
# so it has homesceodasticity

# %%
#Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = [variance_inflation_factor(X_constant.values, i) for i in range(X_constant.shape[1])]
pd.DataFrame({'vif': vif[1:]}, index=X.columns).T
# Out:
#           age       bmi  children     smoker  bmi_smoker
# vif  1.015274  1.296839  1.002086  25.135278   25.443394

# %% [raw]
# so multicollinearity exist,first remove max vif and vif>4.
# so remove smoker

# %%
X.drop(columns={'bmi_smoker'},inplace=True)

# %%
import warnings
warnings.filterwarnings('ignore')

X_constant=sm.add_constant(X)
lin_reg=sm.OLS(Y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  claim   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     998.2
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):               0.00
# Time:                        14:32:04   Log-Likelihood:                -13551.
# No. Observations:                1338   AIC:                         2.711e+04
# Df Residuals:                    1333   BIC:                         2.714e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.211e+04    941.954    -12.851      0.000    -1.4e+04   -1.03e+04
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = [variance_inflation_factor(X_constant.values, i) for i in range(X_constant.shape[1])]
pd.DataFrame({'vif': vif[1:]}, index=X.columns).T
# Out:
#           age       bmi  children    smoker
# vif  1.014515  1.012211  1.001948  1.000747

# %%
sns.heatmap(X.corr(), annot=True)

# %% [markdown]
# # Faculty Notebook - Day 04

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# ## Given data :
#
# * **The data set contains information about money spent on advertisement and their generated sales. Money was spent on TV, radio and newspaper ads.**
#
# **Note:** The objective is to use linear regression to understand how advertisement spending impacts sales.

# %% [markdown]
# | Sl No | Variable | Description |
# | ---- | ---------------- | ------------------------------------- |
# | 1 | TV | float |
# | 2 | radio | float |
# | 3 | newspaper | float |
# | 4 | sales | float  |

# %% [markdown]
# ----------------

# %% [markdown]
# ### Step 1: Import Libraries

# %%
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import statsmodels.api as sm
# %matplotlib inline
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt   
from sklearn import metrics

# %% [markdown]
# ### Step 2: Import the Dataset

# %%
data = pd.read_csv('Advertising.csv', index_col=0)

data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# ### Step3: Check the dimensions of data

# %%
data.shape
# Out:
# (200, 4)

# %% [markdown]
# ### Step4: Check whether data has numerical or categorical data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
# TV           200 non-null float64
# Radio        200 non-null float64
# Newspaper    200 non-null float64
# Sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %% [markdown]
# ### Step5: visualize the relationship between the features and the response using scatterplots

# %%
sns.pairplot(data, x_vars=['TV','Radio','Newspaper'], y_vars='Sales', size=7, aspect=0.7)
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [raw]
# tv and sales initialy linear and as it incresese there is less linear

# %% [markdown]
# ### Step6: Plot each independent variable using the regression line

# %%
sns.pairplot(data, x_vars=['TV','Radio','Newspaper'], y_vars='Sales', size=7, aspect=0.7, kind='reg')

# %% [markdown]
# ### Let's estimate the model coefficients for the advertising data

# %% [markdown]
# ### Step7: Create a fitted model

# %%
lm1 = smf.ols(formula='Sales ~ TV + Radio + Newspaper', data=data).fit()

# print the coefficients
lm1.params
#coefficient and intercept
# Out:
# Intercept    2.938889
# TV           0.045765
# Radio        0.188530
# Newspaper   -0.001037
# dtype: float64

# %% [markdown]
# ### Step10: Check stats summary()

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Fri, 29 Nov 2019   Prob (F-statistic):           1.58e-96
# Time:                        14:21:01   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# TV             0.0458      0.001     32.809      0.000       0.043       0.049
# Radio          0.1885      0.009     21.893      0.000       0.172       0.206
# Newspaper     -0.0010      0.006     -0.177      0.860      -0.013       0.011
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [raw]
# standard error is the expected.it is the expected error you will make when you compute the coefficient.

# %% [markdown]
# ##  Simple Linear Regression Modelling in Machine learning

# %% [markdown]
# ### Step1: Read the data

# %%
data = pd.read_csv('Advertising.csv', index_col=0)
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# ### Step2: Check the relation between dependent and independent variables

# %%
sns.jointplot(data.TV,data.Sales)

# %% [markdown]
# ### Step3: Plot all variables check the relation

# %%
sns.pairplot(data)

# %% [markdown]
# ### Step4: plot the heatmap

# %%
sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# ### Observation:
#
# 1.The diagonal of the above matrix shows the auto_correlation of the variance .Its is always 1. We can observe that
# the correlation between sles vs tv  is highest i.e 0.78.
#
# 2.Correlaton can be vary from -1 and +1 .Closer to +1 means strong positive correlation and close -1 means
# strong negative correlation . Closer to 0 means not very strong correlation . Variables with strong
# correlations are mostly probabily candidtes for the model bulding.

# %% [markdown]
# ### Step 5: Classifying the dependent and Independent Variables

# %%
X = data.drop(columns="Sales")
y = data["Sales"]

# %% [markdown]
# ### Step 6:  Splitting the dataset into the Training set and Test set.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %% [markdown]
# ### Step7: Fitting Simple Linear Regression to the Training set.

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# ### Step8:  Intercept value

# %%
regressor.intercept_
# Out:
# 2.880255286331323

# %% [markdown]
# ### Step9: coefficients value Beta

# %%
regressor.coef_
# Out:
# array([0.04391531, 0.20027962, 0.00184368])

# %%
X.columns

# %%
y_pred = regressor.predict(X_train)
y_pred
# Out:
# array([15.18668568, 12.26977765, 13.60777814, 14.17087817, 18.42355613,
#        19.25876348, 20.21417571, 17.44434223,  9.21867436, 11.7681821 ,
#        19.79560624,  9.77659828, 20.79802538, 23.35293186, 10.14076602,
#        17.37028767, 19.49388835, 18.51737958, 16.81121202, 18.61593234,
#        17.05405175,  8.86804657,  9.99365134,  5.32429766,  3.582856  ,
#        16.54385643, 12.95620026, 18.05860683, 11.83253863, 12.52766581,
#        13.69735567,  6.9892964 , 16.59539421,  9.76219794,  8.01338178,
#        15.53596096, 24.91114482, 11.10696214, 21.34211171, 13.68490684,
#        10.86771675,  8.36994343, 12.33919316, 20.68332127, 10.42077075,
#        14.542794  , 16.47799268, 17.26280293, 13.03916359, 17.41395551,
#        21.24351863,  8.22930878, 16.11423223, 15.17096874,  8.69739797,
#        13.90470148, 16.33915139,  9.47607068, 14.43017824, 18.1175578 ,
#        21.11217609,  9.12308914, 20.22024539, 20.808199  , 13.60003876,
#         4.44653801, 17.91282888, 11.90446373, 10.9811963 , 23.8684339 ,
#        12.01788379, 18.83372073, 20.93051474,  8.14485244,  5.39406062,
#        14.3775589 , 15.80917252,  4.49749418, 14.81144433, 17.12295867,
#         6.97780035, 17.24760511, 16.4832547 , 12.73749478,  7.77467168,
#        12.78862575, 14.53816095, 14.82615971, 21.32485541, 18.33792851,
#         8.70062124, 11.72117852, 23.27197484, 10.18518432, 19.32535846,
#        20.260334  ,  9.76393425, 22.37439992,  7.37698552, 19.27618327,
#        15.75112592,  9.96614433, 11.39432566, 11.23667653,  6.41922532,
#        19.87469039,  7.50455366, 19.28274078, 17.50014247, 23.45583592,
#         9.26037252, 17.25389073, 10.31267429,  9.55917378, 13.28524397,
#        12.64224559, 18.62371079, 10.70199612, 13.90619996, 15.16252171,
#        14.01569126, 14.3003258 , 18.2307433 , 13.35212398, 12.8570958 ,
#        20.50248619, 22.14097923,  9.5321763 , 12.00043397, 17.82370101,
#        15.98955366, 23.38271815, 14.37050333, 12.21434802, 14.60975405,
#        11.92051849,  4.51500546,  6.42289544, 21.76125127,  7.79795833])

# %%
regressor.predict(X_test)
# Out:
# array([10.05866652,  7.43318827,  6.95305695, 24.16874598, 11.98172029,
#         6.54464708, 13.19426793, 14.90240334, 11.07675294, 16.25061663,
#        23.0081158 ,  9.12072148, 10.29342297, 15.3709661 , 11.62396513,
#        12.1057432 , 18.55030805, 10.85810888, 16.13879856, 17.20281404,
#        24.25469939,  9.43869821, 15.13419408, 12.41283844,  5.66973859,
#        15.23876681, 12.1878762 , 20.95164149, 13.22671807,  9.20954724,
#        13.39812727, 21.61944517, 18.05938674, 21.14798547,  6.73582996,
#         6.16799717,  7.98042607, 13.09083488, 14.86214078,  6.23597127,
#        12.35246911,  9.19452235, 15.04717679, 16.23039254, 17.17240889,
#        13.3341216 ,  3.68035786, 12.53946851, 15.93674769,  8.67881357,
#        10.62459997, 19.5646526 , 18.3472282 , 15.24662975, 10.04846378,
#         8.17344188, 21.49061088, 14.137309  , 16.29760212,  8.90502274])

# %% [markdown]
# ### Step 10: R^2 and MSE and RMSE

# %% [markdown]
# $R^2$ term is the coefficient of determination and it reflects how well the model fits the observed data.
#
# The coefficient of determination is given by $R^2$ = 1 - $\frac{SSE}{SST}$
#
# * Let y be the observed response.
# * $\hat{y}$ be the predicted value for the response
# * $\overline{y}$ be the mean of the response
#
# SSE = $\sum_{i=1}^{n}{(y_i - \hat{y}_i)}^2$
#
# SST = $\sum_{i=1}^{n}{(y_i - \overline{y}_i)}^2$

# %% [markdown]
# ### R^2

# %% [markdown]
# * R-squared will always increase (on train set) as you add more features to the model, even if they are unrelated to the response
# Selecting the model with the highest R-squared is not a reliable approach for choosing the best linear model.

# %%
print("R^2:",regressor.score(X_train, y_train))
# Out:
# ('R^2:', 0.9065727532450597)

# %% [markdown]
# ### R-Squared Adjusted
#
# $R^2-adjusted = 1 - \frac {(1-R^2)(n-1)}{n-k-1}$

# %%
X_train.shape
# Out:
# (140, 3)

# %%
def r_squared_adjusted(rss, train_data):
    n = train_data.shape[0]
    k = train_data.shape[1]
    numerator = (1-rss)*(n)
    denominator = n-k-1
    rssAdj = 1 - (numerator / denominator)
    
    return rssAdj

rss = regressor.score(X_train, y_train)
rssAdj = r_squared_adjusted(rss, X_train)
rssAdj
# Out:
# 0.903824893046385

# %% [markdown]
# ### Other metrics can be used such as...

# %% [markdown]
# ### MAE

# %%
MAE = metrics.mean_absolute_error(y_pred,y_train)
print("Mean Absolute Error:", MAE)
# Out:
# ('Mean Absolute Error:', 1.2501938510421038)

# %% [markdown]
# ### MSE

# %%
mse = metrics.mean_squared_error(y_pred,y_train)
print("Mean Squared Error:",mse)
# Out:
# ('Mean Squared Error:', 2.4864363275765333)

# %% [markdown]
# ### RMSE

# %%
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# ('RMSE:', 1.5768437866753109)

# %% [markdown]
# ## Step9: Predicting the Test set results

# %%
y_pred_test = regressor.predict(X_test)

# %%
print("R^2:",regressor.score(X_test, y_test))
# Out:
# ('R^2:', 0.8649018906637792)

# %% [markdown]
# ### Simulate the impact of noisy features

# %%
### Add random variables

# %%
random_vars = pd.DataFrame(np.random.randint(size=(200,50),low=10,high=20))

# %%
random_vars.columns = ["random_var_" + str(i) for i in range(0,random_vars.shape[1])]

# %%
X.reset_index(drop=True,inplace=True)
random_vars.reset_index(drop=True,inplace=True)

# %%
X_with_random_vars = pd.concat([X,random_vars],axis=1)

# %%
X_with_random_vars.shape
# Out:
# (200, 53)

# %%
X_train_with_random, X_test_with_random, y_train, y_test = train_test_split(X_with_random_vars,
                                                                            y, test_size = 0.3, random_state = 0)

# %%
regressor = LinearRegression()
regressor.fit(X_train_with_random, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print("R^2:",regressor.score(X_train_with_random, y_train))
# Out:
# ('R^2:', 0.9380203251823719)

# %%
r_squared_adjusted(rss, X_train_with_random)
# Out:
# 0.847909133189632

# %%
y_pred_test = regressor.predict(X_test_with_random)

# %%
print("R^2 for test set:",regressor.score(X_test_with_random, y_test))
# Out:
# ('R^2 for test set:', 0.7444348047581971)

# %% [raw]
# By adding random variable training predict increses since there would be some correlation with random variable.
# Test prediction decreses we are taking some irrevalant to predict

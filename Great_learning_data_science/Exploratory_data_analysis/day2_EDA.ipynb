# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=sns.load_dataset('tips')

# %%
df1.nunique()
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
df1.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df1['day'].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df1.isnull()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
df1.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df1.describe(
)
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df1['total_bill'].skew()
# Out:
# 1.1332130376158205

# %%
df1['tip'].skew()
# Out:
# 1.4654510370979401

# %%
sns.distplot(df1['total_bill'],hist=True,kde=False)
plt.axvline(df1['total_bill'].mean(),color='red')
plt.axvline(df1['total_bill'].median(),color='green')
plt.show()

# %%
sns.distplot(df1['total_bill'],hist=False,kde=True)
plt.axvline(df1['total_bill'].mean(),color='red')
plt.axvline(df1['total_bill'].median(),color='green')
plt.show()

# %%
sns.distplot(df1['tip'],hist=True,kde=False)
plt.axvline(df1['tip'].mean(),color='red')
plt.axvline(df1['tip'].median(),color='green')
plt.show()

# %%
sns.distplot(df1['tip'],hist=False,kde=True)
plt.axvline(df1['tip'].mean(),color='red')
plt.axvline(df1['tip'].median(),color='green')
plt.show()

# %%
sns.boxplot(y=df1['total_bill'])

# %%
sns.boxplot(y=df1['tip'])

# %%
sns.violinplot(x=df1['total_bill'])

# %%
plt.hist(df1['total_bill'],bins=4) #equal distribution
plt.show()

# %%
plt.hist(df1['total_bill'],bins=[0,15,40,55]) # not equal distribution
plt.show()

# %%
sns.kdeplot(df1['total_bill'],shade=True,color='green')

# %%
df1['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df1['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
plt.bar(df1['size'].value_counts().index,df1['size'].value_counts())
plt.show()

# %%
df1['size'].value_counts().plot(kind='bar')
plt.xlabel('Size')
plt.ylabel('Frequency')
plt.title('Count plot')
plt.show()

# %%
sns.countplot(x=df1['size'])

# %%
plt.bar(df1['day'].value_counts().index,df1['day'].value_counts())
plt.show()

# %%
sns.countplot(x=df1['day'])
plt.show()

# %%
df1['day'].value_counts().plot(kind='bar')
plt.xlabel('Day')
plt.ylabel('Frequency')
plt.title('Count plot')
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(x=df1['day'].value_counts().index,height=df1['day'].value_counts())
plt.show(
)

# %%
expense_values=[1400,600,300,410,250]
expense_label=['homerent','food','fuel','internet','other']

# %%
plt.pie(expense_values,labels=expense_label,autopct='%1.2f',explode=[0,0,0,0,0.2]) # explode is used to take pie out.
plt.show()

# %%
plt.pie(df1['day'].value_counts(),labels=df1['day'].value_counts().index,autopct='%1.2f',explode=[0,0,0,0.2])
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(8,5))  # we can change the size of graph here 
df1['day'].value_counts().plot(kind='pie',ax=ax[1],autopct='%1.2f',explode=[0,0,0,0.2])
sns.countplot(df1['day'],ax=ax[0])
plt.show()

# %%
f

# %%
fig,axes=plt.subplots(figsize=(10,10))# changing the size of graphs
df1['day'].value_counts().plot(kind='pie')
plt.show()

# %%
fig,ax=plt.subplots(2,2,figsize=(9,9))
df1['size'].value_counts().plot(kind='pie',autopct='%1.1f',ax=ax[0,0],explode=[0,0,0,0,0,0.2])
sns.countplot(df1['size'],ax=ax[0,1])
sns.countplot(df1['day'],ax=ax[1,0])
sns.countplot(df1['day'],ax=ax[1,1])

plt.show()
